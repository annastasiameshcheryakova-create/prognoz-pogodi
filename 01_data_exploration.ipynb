# %%
import pandas as pd
import matplotlib.pyplot as plt
plt.style.use('seaborn-v0_8')

# %%
df = pd.read_csv('../data/weather_kriviyrih.csv')
df['timestamp'] = pd.to_datetime(df['timestamp'])
df = df.sort_values('timestamp').reset_index(drop=True)
df.head()

# %%
df.info()

# %%
df.describe()

# %%
df.isna().sum()

# %%
plt.figure(figsize=(14,5))
plt.plot(df['timestamp'], df['temp_c'])
plt.title('Температура — Кривий Ріг')
plt.xlabel('Час')
plt.ylabel('°C')
plt.show()

# %%
df[['temp_c','humidity','wind_kmh','precip_prob']].corr()

# %% [markdown]
# ### Висновок
# - Дані годинні
# - Пропусків немає або інтерполюються
# - Дані підходять для time-series прогнозування
